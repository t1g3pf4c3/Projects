# %%
from graphviz import Digraph
# Create Digraph object


dot = Digraph(node_attr={'shape' : 'circle'})
# Add nodes 1 and 2

# Add edge between 1 and 2

# Visualize the graph


# for i in range(len(insert)):
#     if insert[i] == '(':
#         skobnum += 1
#         # dot.node(str(nodenum))
#         # nodenum +=1
#         for j in range(len(insert) - (i)):
#             if insert[j] == ')' and skobnum == 1:
#                 inner = insert[i+1:j]
#                 for k in range(len(inner)):
#                     if insert[k] == '|':
#                         dot.edge(str(i), str(j), inner[0:k-1])
#                         dot.edge(str(i), str(j), inner[k: len(inner)])


# def regParse(insert):
#     dum = [];
#     for i in range(len(insert)):

        
insert='a|b|c'


def orReg(dot, node1, node2, insert):
    for k in range(len(insert)):
        if insert[k]!='|':
            dot.edge(node1, node2, insert[k])
    return dot
# dot = orReg(dot, '1', '2', insert)



# dot.edge('S', 'S', 'a')
# dot.edge('O', 'O', 'b')
# dot.edge('S', 'O', 'b')
# dot

# dot.edge('S', 'S', 'b')
# dot.edge('S', 'K', 'e')
# dot.edge('N', 'K', 'a' )
# dot.edge('K', 'O', 'b')
# dot.edge('Z', 'N', 'e')
# dot.edge('Z', 'S', 'e')

# dot.edge('S', 'A', 'a')
# dot.edge('A', 'K', 'bb')
# dot.edge('K', 'K', 'bb')
# dot.edge('K', 'O', 'a')

dot.edge('K', 'O', 'a|b')
dot.edge('Z', 'K', 'a|b')
dot.edge('N', 'Z', 'a')
dot.edge('N', 'N', 'a|b')
dot
